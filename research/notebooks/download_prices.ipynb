# %% [markdown]
# # Download Price Data
#
# Fetches price data in **batches** (up to 20 tickers per yfinance call), accumulates by month in memory, then writes each affected monthly CSV once at the end. Uses a **single date range** for all tickers when resuming (fewer API calls, less throttling). Output: `data/<year>/PRICES_<year>-M<month>.csv`. Start date in `config/constants.py`. Set `FORCE_REDOWNLOAD = True` to re-download from start.

# %%
import sys
from pathlib import Path
from datetime import date, timedelta

_root = Path.cwd().resolve()
while _root != _root.parent and not (_root / ".git").exists():
    _root = _root.parent
sys.path.insert(0, str(_root))

from research.functions.download_helper import (
    find_project_root,
    cleanup_existing_files,
    get_last_dates_per_ticker,
)
from research.functions.fetch_and_store import fetch_and_store
from research.config.constants import get_universe, START_DATE as START_DATE_STR

PROJECT_ROOT = find_project_root(Path.cwd())

# %%
DATA_DIR = PROJECT_ROOT / "data"
START_DATE = date.fromisoformat(START_DATE_STR)
TICKERS = get_universe()
FORCE_REDOWNLOAD = False

DATA_DIR.mkdir(parents=True, exist_ok=True)

# %%
today = date.today()
end_date = today - timedelta(days=1)  # fetch through yesterday (T-1)

# %%
if FORCE_REDOWNLOAD:
    n = cleanup_existing_files(DATA_DIR)
    if n:
        print(f"Deleted {n} files.")

last_dates = get_last_dates_per_ticker(DATA_DIR, TICKERS) if not FORCE_REDOWNLOAD else {}
resuming = any(v is not None for v in last_dates.values())
print(f"Fetching: {START_DATE} → {end_date}", end="")
if resuming:
    print(" (resume; coalesced single range)", end="")
print()

# Single date range for all tickers (fewer API calls). Only include tickers that need data.
global_start, global_end = START_DATE, end_date
ticker_ranges: dict[str, tuple[date, date]] = {}
min_date_per_ticker: dict[str, date] = {}
skipped = 0
for ticker in TICKERS:
    last = last_dates.get(ticker)
    start = START_DATE if (FORCE_REDOWNLOAD or last is None) else last + timedelta(days=1)
    if start > end_date:
        skipped += 1
        continue
    ticker_ranges[ticker] = (global_start, global_end)
    # Only keep rows after this date when merging (avoids storing already-have data)
    min_date_per_ticker[ticker] = last if last is not None else START_DATE - timedelta(days=1)

result = fetch_and_store(
    ticker_ranges, DATA_DIR,
    min_date_per_ticker=min_date_per_ticker,
    on_ticker=lambda t, n: print(f"  {t}: {n} rows"),
)
print(f"\nUpdated: {len(result.stored)} | Up to date: {skipped} | "
      f"No new data: {len(ticker_ranges) - len(result.stored)}")
if result.failed:
    print(f"WARNING: {len(result.failed)} tickers returned no data: {result.failed}")
print("Done.")
# Out:
# Fetching: 2020-01-01 → 2026-02-19 (resume; coalesced single range)
# Fetching data 2020-01-01 to 2026-02-19 for SPY,IVV,VOO,SPLG,RSP,VTI,ITOT,SCHB,IWV,IWD,IWF,SCHX,VV,VTV,VUG,MDY,IJH,IWR,IWM,VB,SCHA,VXF,DIA,QQQ,QQQM,XLK,VGT,IYW,IGV,SMH,SOXX,XLV,VHT,IYH,XBI,XLF,VFH,IYF,KBE,KRE,KIE,IAK,KBWP,XLE,VDE,IYE,XLI,VIS,IYJ,PAVE,XLY,VCR,IYC,XHB,XLP,VDC,IYK,XLB,VAW,IYM,XME,COPX,REMX,XLU,VPU,XLRE,VNQ,IYR,SCHH,REET,MORT,REM,ICLN,TAN,QCLN,PBW,LIT,BATT,BOTZ,ROBO,FINX,HACK,CIBR,SKYY,WCLD,AIQ,DRIV,IDRV,BLOK,BITQ,EFA,EEM,VEA,VWO,IEMG,VXUS,IXUS,SCHF,SCHE,IEFA,EWJ,EWZ,EWG,EWC,FXI,INDA,EWT,EWY,EWW,VGK,VPL,VEU,IEU,EPP,ASHR,AGG,BND,BNDX,TLT,IEF,SHY,SHV,VGSH,VGIT,VGLT,LQD,HYG,JNK,TIP,VTIP,EMB,MUB,TFI,FLOT,DBC,PDBC,GLD,IAU,IAUM,GLDM,SLV,USO,BNO,UNG,DBA,DBB,CPER,WEAT,CORN,SOYB,PPLT,PALL,SCHD,VYM,DVY,DGRO,HDV,SPHD,NOBL,SDY,FVD,PEY,SPYD,VIG,SCHY,VXX,UVXY,SVXY,TQQQ,SQQQ,UPRO,SPXU,SH,SDS,SSO,QID,QLD,TMF,TMV,AOR,AOA,AOM,AOK,NTSX,RPAR,BITO,BITI,AAPL,MSFT,NVDA,AVGO,ORCL,CRM,ADBE,AMD,INTC,CSCO,QCOM,TXN,NOW,PANW,CRWD,IBM,ACN,INTU,SNOW,PLTR,GOOGL,META,NFLX,DIS,TMUS,VZ,T,CMCSA,CHTR,AMZN,TSLA,HD,LOW,NKE,MCD,SBUX,TJX,BKNG,ABNB,GM,F,RCL,ROST,LULU,PG,KO,PEP,WMT,COST,MDLZ,PM,MO,CL,KMB,KR,HSY,UNH,JNJ,PFE,MRK,ABBV,LLY,TMO,DHR,AMGN,GILD,BMY,ISRG,MDT,ABT,SYK,ZTS,JPM,BAC,WFC,C,GS,MS,SCHW,AXP,V,MA,BLK,SPGI,CME,ICE,ALL,TRV,CB,PGR,AIG,WRB,MMC,AJG,BRO,MET,PRU,AFL,HIG,LNC,UNM,GL,XOM,CVX,COP,SLB,EOG,MPC,VLO,PSX,OXY,KMI,CAT,DE,HON,GE,RTX,LMT,BA,UNP,CSX,NSC,UPS,FDX,ETN,EMR,GD,NOC,LIN,APD,SHW,NUE,FCX,DOW,DD,NEE,DUK,SO,EXC,AEP,PLD,AMT,CCI,EQIX,SPG,MMM,AOS,AES,A,AKAM,ALB,ARE,ALGN,ALLE,LNT,GOOG,AMCR,AEE,AWK,AMP,AME,APH,ADI,AON,APA,APO,AMAT,APTV,ACGL,ADM,ANET,AIZ,ATO,ADSK,ADP,AZO,AVB,AVY,AXON,BKR,BALL,BAX,BDX,BRK.B,BBY,TECH,BIIB,BX,XYZ,BK,BSX,BR,BF.B,BLDR,BG,BXP,CHRW,CDNS,CZR,CPT,CPB,COF,CAH,KMX,CCL,CARR,CBOE,CBRE,CDW,COR,CNC,CNP,CF,CRL,CMG,CHD,CI,CINF,CTAS,CFG,CLX,CMS,CTSH,COIN,CAG,ED,STZ,CEG,COO,CPRT,GLW,CPAY,CTVA,CSGP,CTRA,CMI,CVS,DRI,DDOG,DVA,DAY,DECK,DELL,DAL,DVN,DXCM,FANG,DLR,DG,DLTR,D,DPZ,DASH,DOV,DHI,DTE,EMN,EBAY,ECL,EIX,EW,EA,ELV,ENPH,ETR,EPAM,EQT,EFX,EQR,ERIE,ESS,EL,EG,EVRG,ES,EXE,EXPE,EXPD,EXR,FFIV,FDS,FICO,FAST,FRT,FIS,FITB,FSLR,FE,FI,FTNT,FTV,FOXA,FOX,BEN,GRMN,IT,GEHC,GEV,GEN,GNRC,GIS,GPC,GPN,GDDY,HAL,HAS,HCA,DOC,HSIC,HPE,HLT,HOLX,HRL,HST,HWM,HPQ,HUBB,HUM,HBAN,HII,IEX,IDXX,ITW,INCY,IR,PODD,IFF,IP,IPG,IVZ,INVH,IQV,IRM,JBHT,JBL,JKHY,J,JCI,K,KVUE,KDP,KEY,KEYS,KIM,KKR,KLAC,KHC,LHX,LH,LRCX,LW,LVS,LDOS,LEN,LII,LYV,LKQ,L,LYB,MTB,MKTX,MAR,MLM,MAS,MTCH,MKC,MCK,MTD,MGM,MCHP,MU,MAA,MRNA,MHK,MOH,TAP,MPWR,MNST,MCO,MOS,MSI,MSCI,NDAQ,NTAP,NEM,NWSA,NWS,NI,NDSN,NTRS,NCLH,NRG,NVR,NXPI,ORLY,ODFL,OMC,ON,OKE,OTIS,PCAR,PKG,PSKY,PH,PAYX,PAYC,PYPL,PNR,PCG,PNW,PNC,POOL,PPG,PPL,PFG,PEG,PTC,PSA,PHM,PWR,DGX,RL,RJF,O,REG,REGN,RF,RSG,RMD,RVTY,ROK,ROL,ROP,SBAC,STX,SRE,SWKS,SJM,SW,SNA,SOLV,LUV,SWK,STT,STLD,STE,SMCI,SYF,SNPS,SYY,TROW,TTWO,TPR,TRGP,TGT,TEL,TDY,TER,TPL,TXT,TKO,TTD,TSCO,TT,TDG,TRMB,TFC,TYL,TSN,USB,UBER,UDR,ULTA,UAL,URI,UHS,VTR,VLTO,VRSN,VRSK,VRTX,VTRS,VICI,VST,VMC,GWW,WAB,WBA,WBD,WM,WAT,WEC,WELL,WST,WDC,WY,WSM,WMB,WTW,WDAY,WYNN,XEL,XYL,YUM,ZBRA,ZBH,AAMI,AAP,AAT,ABCB,ABG,ABM,ABR,ACA,ACAD,ACHC,ACIW,ACLS,ACMR,ACT,ADAM,ADEA,ADMA,ADNT,ADT,ADUS,AEO,AESI,AGO,AGYS,AHCO,AHH,AIN,AIR,AKR,AL,ALEX,ALG,ALGT,ALKS,ALRM,AMN,AMPH,AMR,AMRX,AMSF,AMTM,AMWD,ANDE,ANGI,ANIP,AORT,AOSL,APAM,APLE,APLS,APOG,ARCB,ARI,ARLO,AROC,ARR,ASO,ASTE,ASTH,ATEN,ATGE,AUB,AVA,AVNS,AWI,AWR,AX,AXL,AZTA,AZZ,BANC,BANF,BANR,BBT,BCC,BCPC,BFH,BFS,BGC,BHE,BJRI,BKE,BKU,BL,BLFS,BLMN,BMI,BOH,BOOT,BOX,BRC,BTSG,BTU,BXMT,CABO,CAKE,CALM,CALX,CARG,CARS,CASH,CATY,CBRL,CBU,CC,CCOI,CCS,CE,CENT,CENTA,CENX,CERT,CFFN,CHCO,CHEF,CLB,CLSK,CNK,CNMD,CNR,CNS,CNXN,COHU,COLL,CON,CORT,CPF,CPK,CPRX,CRC,CRGY,CRI,CRK,CRSR,CRVL,CSGS,CSR,CSW,CTKB,CTRE,CTS,CUBI,CURB,CVBF,CVCO,CVI,CWEN,CWEN.A,CWK,CWST,CWT,CXM,CXW,DAN,DCOM,DEA,DEI,DFH,DFIN,DGII,DIOD,DLX,DNOW,DOCN,DORM,DRH,DV,DXC,DXPE,EAT,ECG,ECPG,EFC,EGBN,EIG,EMBC,ENOV,ENR,ENVA,EPAC,EPC,EPRT,ESE,ESI,ETD,ETSY,EVTC,EXPI,EXTR,EYE,EZPW,FBK,FBNC,FBP,FBRT,FCF,FCPT,FDP,FELE,FFBC,FHB,FIBK,FIZZ,FMC,FORM,FOXF,FRPT,FSS,FTDR,FTRE,FUL,FULT,FUN,FWRD,GBX,GDEN,GDYN,GEO,GFF,GIII,GKOS,GNL,GNW,GO,GOGO,GOLF,GPI ...
#   NWS: 1540 rows
#   MLKN: 1540 rows
#   MAR: 1540 rows
#   APTV: 1540 rows
#   VSH: 1540 rows
#   XYZ: 1540 rows
#   IVV: 5 rows
#   RRR: 1540 rows
#   WEAT: 5 rows
#   UDR: 1540 rows
#   WS: 557 rows
#   SCHD: 5 rows
#   UHT: 1540 rows
#   FAST: 1540 rows
#   TFI: 5 rows
#   ADBE: 5 rows
#   HACK: 5 rows
#   KKR: 1540 rows
#   ROL: 1540 rows
#   GM: 5 rows
#   MGM: 1540 rows
#   VLTO: 595 rows
#   USPH: 1540 rows
#   SMPL: 1540 rows
#   WAT: 1540 rows
#   BND: 5 rows
#   HCA: 1540 rows
#   BRO: 5 rows
#   HRMY: 1381 rows
#   IYM: 5 rows
#   EPP: 5 rows
#   ED: 1540 rows
#   PLAB: 1540 rows
#   SLG: 1540 rows
#   XLRE: 5 rows
#   SLVM: 1105 rows
#   MOH: 1540 rows
#   SSO: 5 rows
#   UTL: 1540 rows
#   CENTA: 1540 rows
#   DVY: 5 rows
#   TNC: 1540 rows
#   CDW: 1540 rows
#   CLB: 1540 rows
#   DLR: 1540 rows
#   EA: 1540 rows
#   UVV: 1540 rows
#   MCO: 1540 rows
#   KIE: 5 rows
#   ABR: 1540 rows
#   SONO: 1540 rows
#   ALGT: 1540 rows
#   VPL: 5 rows
#   TECH: 1540 rows
#   WEC: 1540 rows
#   HIW: 1540 rows
#   HUBB: 1540 rows
#   VAC: 1540 rows
#   UNFI: 1540 rows
#   PBI: 1540 rows
#   WLY: 1540 rows
#   SNCY: 1237 rows
#   MET: 5 rows
#   AORT: 1540 rows
#   VUG: 5 rows
#   PAYC: 1540 rows
#   CTS: 1540 rows
#   KREF: 1540 rows
#   FE: 1540 rows
#   UCB: 1540 rows
#   CNP: 1540 rows
#   IWM: 5 rows
#   VMC: 1540 rows
#   SMTC: 1540 rows
#   HCC: 1540 rows
#   TFX: 1540 rows
#   CCI: 5 rows
#   AEO: 1540 rows
#   PRA: 1540 rows
#   HE: 1540 rows
#   GFF: 1540 rows
#   AOS: 1540 rows
#   DCOM: 1540 rows
#   NE: 1179 rows
#   VXF: 5 rows
#   PHIN: 663 rows
#   PRGS: 1540 rows
#   BANC: 1540 rows
#   CMS: 1540 rows
#   PZZA: 1540 rows
#   ACGL: 1540 rows
#   DXPE: 1540 rows
#   EAT: 1540 rows
#   HWKN: 1540 rows
#   VSNT: 44 rows
#   FANG: 1540 rows
#   PRG: 1540 rows
#   AIR: 1540 rows
#   SBUX: 5 rows
#   CASH: 1540 rows
#   COP: 5 rows
#   IAUM: 5 rows
#   HWM: 1540 rows
#   ARR: 1540 rows
#   IXUS: 5 rows
#   HOLX: 1540 rows
#   AMR: 1263 rows
#   URBN: 1540 rows
#   DGII: 1540 rows
#   RNST: 1540 rows
#   IWV: 5 rows
#   GEHC: 795 rows
#   PRK: 1540 rows
#   HTO: 1540 rows
#   SCHB: 5 rows
#   ASO: 1350 rows
#   CHTR: 5 rows
#   EPAM: 1540 rows
#   PCAR: 1540 rows
#   ABBV: 5 rows
#   SH: 5 rows
#   ORCL: 5 rows
#   AGO: 1540 rows
#   FCPT: 1540 rows
#   CXW: 1540 rows
#   NFLX: 5 rows
#   DHR: 5 rows
#   CSGP: 1540 rows
#   EVTC: 1540 rows
#   XLV: 5 rows
#   BMI: 1540 rows
#   MGEE: 1540 rows
#   MYGN: 1540 rows
#   CMI: 1540 rows
#   GVA: 1540 rows
#   ODFL: 1540 rows
#   SYY: 1540 rows
#   HCI: 1540 rows
#   TDS: 1540 rows
#   NMIH: 1540 rows
#   BLOK: 5 rows
#   JPM: 5 rows
#   STLD: 1540 rows
#   ADT: 1540 rows
#   XLK: 5 rows
#   ALRM: 1540 rows
#   BL: 1540 rows
#   LQDT: 1540 rows
#   RHP: 1540 rows
#   OMCL: 1540 rows
#   TRUP: 1540 rows
#   ABT: 5 rows
#   TRV: 5 rows
#   HAYW: 1240 rows
#   CPRT: 1540 rows
#   AMP: 1540 rows
#   SXC: 1540 rows
#   PBH: 1540 rows
#   QNST: 1540 rows
#   NRG: 1540 rows
#   IPAR: 1540 rows
#   DDOG: 1540 rows
#   MDLZ: 5 rows
#   SOLS: 83 rows
#   ZD: 1540 rows
#   BLDR: 1540 rows
#   TRNO: 1540 rows
#   VNQ: 5 rows
#   XLY: 5 rows
#   ANDE: 1540 rows
#   MATX: 1540 rows
#   D: 1540 rows
#   VITL: 1394 rows
#   GLW: 1540 rows
#   CC: 1540 rows
#   EVRG: 1540 rows
#   VCYT: 1540 rows
#   ACN: 5 rows
#   XEL: 1540 rows
#   MTUS: 1540 rows
#   PNC: 1540 rows
#   BAX: 1540 rows
#   FXI: 5 rows
#   KVUE: 700 rows
#   ADMA: 1540 rows
#   EMB: 5 rows
#   APLE: 1540 rows
#   SHAK: 1540 rows
#   JKHY: 1540 rows
#   TEL: 1540 rows
#   CVBF: 1540 rows
#   CURB: 349 rows
#   NXPI: 1540 rows
#   PIPR: 1540 rows
#   MHK: 1540 rows
#   DBC: 5 rows
#   PAYO: 1340 rows
#   PRGO: 1540 rows
#   MYRG: 1540 rows
#   HFWA: 1540 rows
#   DVN: 1540 rows
#   TBBK: 1540 rows
#   EXTR: 1540 rows
#   SEM: 1540 rows
#   LEN: 1540 rows
#   IYK: 5 rows
#   TTWO: 1540 rows
#   NABL: 1152 rows
#   PRVA: 1208 rows
#   VV: 5 rows
#   IEFA: 5 rows
#   NSC: 5 rows
#   SBAC: 1540 rows
#   VDC: 5 rows
#   AMTM: 351 rows
#   ASHR: 5 rows
#   EXE: 1261 rows
#   GRMN: 1540 rows
#   MTRN: 1540 rows
#   AEE: 1540 rows
#   ON: 1540 rows
#   MO: 5 rows
#   ISRG: 5 rows
#   IEX: 1540 rows
#   FORM: 1540 rows
#   TNDM: 1540 rows
#   XPEL: 1540 rows
#   WFC: 5 rows
#   GNW: 1540 rows
#   IBM: 5 rows
#   DOW: 5 rows
#   NHC: 1540 rows
#   RUN: 1540 rows
#   FOXF: 1540 rows
#   VSTS: 600 rows
#   CAH: 1540 rows
#   ABCB: 1540 rows
#   CME: 5 rows
#   ASTE: 1540 rows
#   SABR: 1540 rows
#   HBAN: 1540 rows
#   AAP: 1540 rows
#   BJRI: 1540 rows
#   TMV: 5 rows
#   TRN: 1540 rows
#   TDW: 1540 rows
#   BX: 1540 rows
#   PH: 1540 rows
#   CBRE: 1540 rows
#   NWSA: 1540 rows
#   MTD: 1540 rows
#   WKC: 1540 rows
#   OTTR: 1540 rows
#   MDT: 5 rows
#   XHR: 1540 rows
#   FLOT: 5 rows
#   META: 5 rows
#   CTAS: 1540 rows
#   V: 5 rows
#   WAB: 1540 rows
#   FUL: 1540 rows
#   FTNT: 1540 rows
#   VRTS: 1540 rows
#   SOXX: 5 rows
#   JBLU: 1540 rows
#   BA: 5 rows
#   POOL: 1540 rows
#   WU: 1540 rows
#   SLV: 5 rows
#   GS: 5 rows
#   WRB: 5 rows
#   NEM: 1540 rows
#   ARCB: 1540 rows
#   DUK: 5 rows
#   CRM: 5 rows
#   PSKY: 1540 rows
#   MDY: 5 rows
#   NAVI: 1540 rows
#   STT: 1540 rows
#   BMY: 5 rows
#   PTC: 1540 rows
#   TMUS: 5 rows
#   TSN: 1540 rows
#   NTRS: 1540 rows
#   GTES: 1540 rows
#   IP: 1540 rows
#   TGTX: 1540 rows
#   CABO: 1540 rows
#   HUM: 1540 rows
#   WBD: 1540 rows
#   KMT: 1540 rows
#   SQQQ: 5 rows
#   AVY: 1540 rows
#   ATGE: 1540 rows
#   PTEN: 1540 rows
#   PEP: 5 rows
#   DOCN: 1232 rows
#   KMX: 1540 rows
#   SKY: 1540 rows
#   HON: 5 rows
#   IIPR: 1540 rows
#   DD: 5 rows
#   EMR: 5 rows
#   PDBC: 5 rows
#   SRPT: 1540 rows
#   KMB: 5 rows
#   ADAM: 1540 rows
#   WMT: 5 rows
#   HLIT: 1540 rows
#   HTZ: 1163 rows
#   DXC: 1540 rows
#   ENR: 1540 rows
#   VTIP: 5 rows
#   WAY: 425 rows
#   MCHP: 1540 rows
#   PSX: 5 rows
#   BK: 1540 rows
#   AWK: 1540 rows
#   MCK: 1540 rows
#   BKU: 1540 rows
#   ACLS: 1540 rows
#   PPG: 1540 rows
#   AMCR: 1540 rows
#   SIG: 1540 rows
#   PKG: 1540 rows
#   BG: 1540 rows
#   CMG: 1540 rows
#   CRL: 1540 rows
#   RJF: 1540 rows
#   CIBR: 5 rows
#   TQQQ: 5 rows
#   EMN: 1540 rows
#   TXN: 5 rows
#   TSCO: 1540 rows
#   MCY: 1540 rows
#   AAT: 1540 rows
#   FRPT: 1540 rows
#   AUB: 1540 rows
#   PFG: 1540 rows
#   APA: 1540 rows
#   ADNT: 1540 rows
#   DOV: 1540 rows
#   AIQ: 5 rows
#   VICI: 1540 rows
#   INDA: 5 rows
#   LNT: 1540 rows
#   ALEX: 1540 rows
#   CORT: 1540 rows
#   TMF: 5 rows
#   AL: 1540 rows
#   LQD: 5 rows
#   REX: 1540 rows
#   ABNB: 5 rows
#   XLI: 5 rows
#   MTCH: 1540 rows
#   COF: 1540 rows
#   ITRI: 1540 rows
#   AVA: 1540 rows
#   FOXA: 1540 rows
#   SHO: 1540 rows
#   SITM: 1540 rows
#   VECO: 1540 rows
#   TWO: 1540 rows
#   WYNN: 1540 rows
#   PAHC: 1540 rows
#   EBAY: 1540 rows
#   VRRM: 1540 rows
#   ACT: 1110 rows
#   MNRO: 1540 rows
#   WMB: 1540 rows
#   SFNC: 1540 rows
#   TYL: 1540 rows
#   AZTA: 1540 rows
#   BKR: 1540 rows
#   INN: 1540 rows
#   MGY: 1540 rows
#   MPT: 1540 rows
#   KOP: 1540 rows
#   PCG: 1540 rows
#   REET: 5 rows
#   CCS: 1540 rows
#   CWT: 1540 rows
#   BCPC: 1540 rows
#   IYJ: 5 rows
#   TPL: 1540 rows
#   VXX: 5 rows
#   ESE: 1540 rows
#   RF: 1540 rows
#   INSW: 1540 rows
#   SO: 5 rows
#   LVS: 1540 rows
#   NOG: 1540 rows
#   NI: 1540 rows
#   ABM: 1540 rows
#   KO: 5 rows
#   PRIM: 1540 rows
#   IRDM: 1540 rows
#   ALLE: 1540 rows
#   KIM: 1540 rows
#   ALL: 5 rows
#   WD: 1540 rows
#   CALM: 1540 rows
#   DIA: 5 rows
#   VIRT: 1540 rows
#   JJSF: 1540 rows
#   PRSU: 1540 rows
#   AFL: 5 rows
#   WSFS: 1540 rows
#   RTX: 5 rows
#   GOLF: 1540 rows
#   STBA: 1540 rows
#   FDP: 1540 rows
#   KTB: 1540 rows
#   FITB: 1540 rows
#   ACHC: 1540 rows
#   WDFC: 1540 rows
#   REZI: 1540 rows
#   OPLN: 1540 rows
#   SNPS: 1540 rows
#   CHRW: 1540 rows
#   JNJ: 5 rows
#   LW: 1540 rows
#   AESI: 739 rows
#   EWC: 5 rows
#   GE: 5 rows
#   STEL: 1540 rows
#   PENN: 1540 rows
#   ETSY: 1540 rows
#   ENPH: 1540 rows
#   ZBH: 1540 rows
#   SCHY: 5 rows
#   CLSK: 1540 rows
#   RMD: 1540 rows
#   SHOO: 1540 rows
#   ECPG: 1540 rows
#   LXP: 1540 rows
#   VB: 5 rows
#   EYE: 1540 rows
#   VIR: 1540 rows
#   LNN: 1540 rows
#   VYX: 1540 rows
#   COO: 1540 rows
#   MTB: 1540 rows
#   ROST: 5 rows
#   LZB: 1540 rows
#   TDC: 1540 rows
#   VYM: 5 rows
#   CTKB: 1148 rows
#   QQQM: 5 rows
#   MRCY: 1540 rows
#   UHS: 1540 rows
#   SCHF: 5 rows
#   CE: 1540 rows
#   SMH: 5 rows
#   VTRS: 1540 rows
#   DELL: 1540 rows
#   WDAY: 1540 rows
#   CHD: 1540 rows
#   APLS: 1540 rows
#   EQT: 1540 rows
#   VIG: 5 rows
#   REM: 5 rows
#   SXI: 1540 rows
#   KEY: 1540 rows
#   EXC: 5 rows
#   MSEX: 1540 rows
#   CRWD: 5 rows
#   VWO: 5 rows
#   CTSH: 1540 rows
#   LIN: 5 rows
#   HZO: 1540 rows
#   REYN: 1520 rows
#   NTSX: 5 rows
#   TLT: 5 rows
#   APO: 1540 rows
#   CNMD: 1540 rows
#   SXT: 1540 rows
#   APAM: 1540 rows
#   TGT: 1540 rows
#   EFA: 5 rows
#   FIZZ: 1540 rows
#   AME: 1540 rows
#   TWI: 1540 rows
#   LGND: 1540 rows
#   CRVL: 1540 rows
#   ALGN: 1540 rows
#   BOX: 1540 rows
#   NUE: 5 rows
#   VRSN: 1540 rows
#   LKFN: 1540 rows
#   AOSL: 1540 rows
#   ARLO: 1540 rows
#   LDOS: 1540 rows
#   XLU: 5 rows
#   HTLD: 1540 rows
#   HASI: 1540 rows
#   AMN: 1540 rows
#   CENT: 1540 rows
#   CHEF: 1540 rows
#   SDS: 5 rows
#   CL: 5 rows
#   MMC: 5 rows
#   DOC: 1540 rows
#   BAC: 5 rows
#   KDP: 1540 rows
#   BCC: 1540 rows
#   FTV: 1540 rows
#   CF: 1540 rows
#   XOM: 5 rows
#   LYV: 1540 rows
#   ACMR: 1540 rows
#   WRLD: 1540 rows
#   PODD: 1540 rows
#   HLT: 1540 rows
#   MRNA: 1540 rows
#   VSCO: 1150 rows
#   IFF: 1540 rows
#   VST: 1540 rows
#   CSX: 5 rows
#   GBX: 1540 rows
#   HLX: 1540 rows
#   SAFT: 1540 rows
#   ERIE: 1540 rows
#   SOYB: 5 rows
#   FSS: 1540 rows
#   EWT: 5 rows
#   WGO: 1540 rows
#   FDX: 5 rows
#   HSIC: 1540 rows
#   BFS: 1540 rows
#   FBK: 1540 rows
#   HOPE: 1540 rows
#   VGIT: 5 rows
#   PCRX: 1540 rows
#   LGIH: 1540 rows
#   IWD: 5 rows
#   IART: 1540 rows
#   INDB: 1540 rows
#   SYK: 5 rows
#   COHU: 1540 rows
#   GILD: 5 rows
#   SEE: 1540 rows
#   UNG: 5 rows
#   QDEL: 1540 rows
#   SHEN: 1540 rows
#   BOOT: 1540 rows
#   ACIW: 1540 rows
#   AOR: 5 rows
#   SPLG: 5 rows
#   EGBN: 1540 rows
#   ATO: 1540 rows
#   MAN: 1540 rows
#   VSAT: 1540 rows
#   GEN: 1540 rows
#   SJM: 1540 rows
#   QCLN: 5 rows
#   RL: 1540 rows
#   ICE: 5 rows
#   INVA: 1540 rows
#   MIR: 1380 rows
#   NSIT: 1540 rows
#   LULU: 5 rows
#   IYC: 5 rows
#   PFE: 5 rows
#   DPZ: 1540 rows
#   ANET: 1540 rows
#   PRLB: 1540 rows
#   SBH: 1540 rows
#   SCHE: 5 rows
#   VAW: 5 rows
#   PANW: 5 rows
#   IIIN: 1540 rows
#   SCHL: 1540 rows
#   NOC: 5 rows
#   VFH: 5 rows
#   J: 1540 rows
#   AMAT: 1540 rows
#   AMSF: 1540 rows
#   BITO: 5 rows
#   GTY: 1540 rows
#   INTC: 5 rows
#   RSG: 1540 rows
#   VRE: 1540 rows
#   NTAP: 1540 rows
#   CVS: 1540 rows
#   SYF: 1540 rows
#   FBP: 1540 rows
#   GRBK: 1540 rows
#   KNTK: 1540 rows
#   SPG: 5 rows
#   CHCO: 1540 rows
#   TAN: 5 rows
#   ECL: 1540 rows
#   BNDX: 5 rows
#   ETR: 1540 rows
#   AGG: 5 rows
#   CPRX: 1540 rows
#   SHY: 5 rows
#   TRST: 1540 rows
#   PHM: 1540 rows
#   JBHT: 1540 rows
#   VPU: 5 rows
#   USB: 1540 rows
#   REG: 1540 rows
#   FCX: 5 rows
#   AIZ: 1540 rows
#   ANGI: 1540 rows
#   EWW: 5 rows
#   IRM: 1540 rows
#   MUB: 5 rows
#   CINF: 1540 rows
#   IYH: 5 rows
#   F: 5 rows
#   CTRA: 1540 rows
#   HPE: 1540 rows
#   IDRV: 5 rows
#   VEA: 5 rows
#   BR: 1540 rows
#   SCSC: 1540 rows
#   PRDO: 1540 rows
#   MA: 5 rows
#   RUSHA: 1540 rows
#   AHCO: 1540 rows
#   ACAD: 1540 rows
#   XLP: 5 rows
#   JCI: 1540 rows
#   GO: 1540 rows
#   FDS: 1540 rows
#   IBP: 1540 rows
#   INTU: 5 rows
#   MORT: 5 rows
#   CRGY: 1052 rows
#   KLIC: 1540 rows
#   FULT: 1540 rows
#   CWST: 1540 rows
#   DRIV: 5 rows
#   ESS: 1540 rows
#   CB: 5 rows
#   EG: 1540 rows
#   CSR: 1540 rows
#   BANF: 1540 rows
#   JBL: 1540 rows
#   WWW: 1540 rows
#   GPI: 1540 rows
#   GPN: 1540 rows
#   NPO: 1540 rows
#   BEN: 1540 rows
#   UFCS: 1540 rows
#   DXCM: 1540 rows
#   TDG: 1540 rows
#   APH: 1540 rows
#   TGNA: 1540 rows
#   DFIN: 1540 rows
#   AOK: 5 rows
#   OTIS: 1487 rows
#   AHH: 1540 rows
#   BIIB: 1540 rows
#   GSHD: 1540 rows
#   UE: 1540 rows
#   AVB: 1540 rows
#   XNCR: 1540 rows
#   PLUS: 1540 rows
#   XHB: 5 rows
#   MCD: 5 rows
#   HIG: 5 rows
#   MODG: 1540 rows
#   BFH: 1540 rows
#   VCR: 5 rows
#   VIS: 5 rows
#   INVH: 1540 rows
#   TXT: 1540 rows
#   UCTT: 1540 rows
#   SFBS: 1540 rows
#   EXPD: 1540 rows
#   UNP: 5 rows
#   CNXN: 1540 rows
#   FBNC: 1540 rows
#   ROBO: 5 rows
#   SWK: 1540 rows
#   GNL: 1540 rows
#   PM: 5 rows
#   GNRC: 1540 rows
#   INSP: 1540 rows
#   TDY: 1540 rows
#   MTX: 1540 rows
#   CPER: 5 rows
#   RAL: 164 rows
#   MAA: 1540 rows
#   VICR: 1540 rows
#   KLAC: 1540 rows
#   ORLY: 1540 rows
#   LCII: 1540 rows
#   KWR: 1540 rows
#   GPC: 1540 rows
#   CCOI: 1540 rows
#   EPAC: 1540 rows
#   TAP: 1540 rows
#   YOU: 1164 rows
#   ELV: 1540 rows
#   TRGP: 1540 rows
#   DASH: 1303 rows
#   AMPH: 1540 rows
#   GOOG: 1540 rows
#   ITOT: 5 rows
#   SWKS: 1540 rows
#   BKE: 1540 rows
#   AJG: 5 rows
#   SVXY: 5 rows
#   SCHX: 5 rows
#   TMO: 5 rows
#   WOR: 1540 rows
#   CFG: 1540 rows
#   SMP: 1540 rows
#   TALO: 1540 rows
#   SNDR: 1540 rows
#   MXL: 1540 rows
#   BXP: 1540 rows
#   XLB: 5 rows
#   DVA: 1540 rows
#   HSTM: 1540 rows
#   MMM: 1540 rows
#   IGV: 5 rows
#   NCLH: 1540 rows
#   AON: 1540 rows
#   AXP: 5 rows
#   PNR: 1540 rows
#   PLTR: 5 rows
#   AMWD: 1540 rows
#   RPAR: 5 rows
#   HNI: 1540 rows
#   EIX: 1540 rows
#   AMGN: 5 rows
#   CFFN: 1540 rows
#   VOO: 5 rows
#   JXN: 1120 rows
#   CSW: 1540 rows
#   OXY: 5 rows
#   HMN: 1540 rows
#   EW: 1540 rows
#   MPWR: 1540 rows
#   AKAM: 1540 rows
#   MU: 1540 rows
#   BTU: 1540 rows
#   VRTX: 1540 rows
#   ENOV: 1540 rows
#   MSGS: 1540 rows
#   SAFE: 1540 rows
#   WSR: 1540 rows
#   UNH: 5 rows
#   EWZ: 5 rows
#   DIOD: 1540 rows
#   KN: 1540 rows
#   IT: 1540 rows
#   UFPT: 1540 rows
#   PTGX: 1540 rows
#   SOLV: 476 rows
#   MAS: 1540 rows
#   CVX: 5 rows
#   UAL: 1540 rows
#   SEZL: 610 rows
#   IWF: 5 rows
#   ICUI: 1540 rows
#   SPGI: 5 rows
#   AWI: 1540 rows
#   TR: 1540 rows
#   ADUS: 1540 rows
#   GLDM: 5 rows
#   ZTS: 5 rows
#   RCUS: 1540 rows
#   EEM: 5 rows
#   COR: 1540 rows
#   WCLD: 5 rows
#   ALKS: 1540 rows
#   FHB: 1540 rows
#   BLMN: 1540 rows
#   FTDR: 1540 rows
#   CNK: 1540 rows
#   SBCF: 1540 rows
#   STX: 1540 rows
#   HD: 5 rows
#   AXON: 1540 rows
#   AMT: 5 rows
#   KR: 5 rows
#   DLTR: 1540 rows
#   PLAY: 1540 rows
#   XBI: 5 rows
#   ETD: 1540 rows
#   BBY: 1540 rows
#   GDDY: 1540 rows
#   MCRI: 1540 rows
#   EFC: 1540 rows
#   MSCI: 1540 rows
#   XLE: 5 rows
#   WT: 1540 rows
#   JBTM: 1540 rows
#   CTVA: 1540 rows
#   WM: 1540 rows
#   FSLR: 1540 rows
#   ADSK: 1540 rows
#   NDSN: 1540 rows
#   WABC: 1540 rows
#   TSLA: 5 rows
#   CARS: 1540 rows
#   WHD: 1540 rows
#   ECG: 327 rows
#   MRP: 260 rows
#   BRC: 1540 rows
#   IWR: 5 rows
#   HII: 1540 rows
#   AZO: 1540 rows
#   IDCC: 1540 rows
#   BOH: 1540 rows
#   MDU: 1540 rows
#   BANR: 1540 rows
#   KAI: 1540 rows
#   INDV: 1540 rows
#   NEOG: 1540 rows
#   UPBD: 1540 rows
#   CUBI: 1540 rows
#   ADM: 1540 rows
#   ES: 1540 rows
#   SAH: 1540 rows
#   CWK: 1540 rows
#   CBU: 1540 rows
#   GL: 5 rows
#   LUMN: 1540 rows
#   HAL: 1540 rows
#   PMT: 1540 rows
#   SCHA: 5 rows
#   ZWS: 1540 rows
#   GD: 5 rows
#   ACA: 1540 rows
#   IR: 1540 rows
#   WERN: 1540 rows
#   AOM: 5 rows
#   ABG: 1540 rows
#   DAY: 1530 rows
#   DNOW: 1540 rows
#   VRSK: 1540 rows
#   CXM: 1169 rows
#   CPF: 1540 rows
#   KGS: 662 rows
#   CLX: 1540 rows
#   PALL: 5 rows
#   CRC: 1332 rows
#   CSCO: 5 rows
#   QRVO: 1540 rows
#   IAK: 5 rows
#   PLMR: 1540 rows
#   IYR: 5 rows
#   MRK: 5 rows
#   BTSG: 517 rows
#   FFBC: 1540 rows
#   GOGO: 1540 rows
#   PAVE: 5 rows
#   FIBK: 1540 rows
#   HCSG: 1540 rows
#   PJT: 1540 rows
#   DHI: 1540 rows
#   BBT: 1540 rows
#   PSA: 1540 rows
#   DEA: 1540 rows
#   LOW: 5 rows
#   DIS: 5 rows
#   UNIT: 1540 rows
#   GDYN: 1540 rows
#   BGC: 1540 rows
#   TILE: 1540 rows
#   KW: 1540 rows
#   VCTR: 1540 rows
#   SKYW: 1540 rows
#   CON: 393 rows
#   NGVT: 1540 rows
#   NVR: 1540 rows
#   ICLN: 5 rows
#   MKC: 1540 rows
#   CWEN: 1540 rows
#   VEU: 5 rows
#   YUM: 1540 rows
#   SNEX: 1540 rows
#   VGLT: 5 rows
#   CTRE: 1540 rows
#   DRI: 1540 rows
#   HYG: 5 rows
#   AMRX: 1540 rows
#   ADP: 1540 rows
#   GIS: 1540 rows
#   AOA: 5 rows
#   RWT: 1540 rows
#   PPLT: 5 rows
#   NBHC: 1540 rows
#   TFC: 1540 rows
#   TPR: 1540 rows
#   PAYX: 1540 rows
#   NKE: 5 rows
#   QQQ: 5 rows
#   ASTH: 1540 rows
#   FINX: 5 rows
#   TMP: 1540 rows
#   IQV: 1540 rows
#   KSS: 1540 rows
#   BHE: 1540 rows
#   LMAT: 1540 rows
#   LLY: 5 rows
#   COLL: 1540 rows
#   LHX: 1540 rows
#   IYW: 5 rows
#   RHI: 1540 rows
#   PRKS: 1540 rows
#   SSTK: 1540 rows
#   HAS: 1540 rows
#   ROCK: 1540 rows
#   FVD: 5 rows
#   PWR: 1540 rows
#   WELL: 1540 rows
#   SMCI: 1540 rows
#   DLX: 1540 rows
#   SM: 1540 rows
#   TIP: 5 rows
#   SRE: 1540 rows
#   VZ: 5 rows
#   LBRT: 1540 rows
#   VLO: 5 rows
#   FRT: 1540 rows
#   SPNT: 1540 rows
#   MATW: 1540 rows
#   ARI: 1540 rows
#   IEMG: 5 rows
#   QCOM: 5 rows
#   IYF: 5 rows
#   AXL: 1540 rows
#   COIN: 1218 rows
#   MKTX: 1540 rows
#   PYPL: 1540 rows
#   PEY: 5 rows
#   MD: 1540 rows
#   UBER: 1540 rows
#   TROW: 1540 rows
#   CARR: 1487 rows
#   HTH: 1540 rows
#   COPX: 5 rows
#   NOBL: 5 rows
#   L: 1540 rows
#   COST: 5 rows
#   BDX: 1540 rows
#   LRN: 1540 rows
#   NEO: 1540 rows
#   EWG: 5 rows
#   UPRO: 5 rows
#   CBRL: 1540 rows
#   LMT: 5 rows
#   AWR: 1540 rows
#   DBA: 5 rows
#   FWRD: 1540 rows
#   EMBC: 981 rows
#   SPYD: 5 rows
#   EPRT: 1540 rows
#   GLD: 5 rows
#   O: 1540 rows
#   CCL: 1540 rows
#   UPS: 5 rows
#   VGSH: 5 rows
#   CMCSA: 5 rows
#   SEDG: 1540 rows
#   URI: 1540 rows
#   DTE: 1540 rows
#   CNS: 1540 rows
#   CEG: 1024 rows
#   AIG: 5 rows
#   WTW: 1540 rows
#   NDAQ: 1540 rows
#   SW: 1540 rows
#   ALB: 1540 rows
#   SANM: 1540 rows
#   BLK: 5 rows
#   ITGR: 1540 rows
#   IVZ: 1540 rows
#   UPWK: 1540 rows
#   TER: 1540 rows
#   QID: 5 rows
#   NATL: 590 rows
#   MC: 1540 rows
#   TFIN: 1540 rows
#   PG: 5 rows
#   SKT: 1540 rows
#   BOTZ: 5 rows
#   XYL: 1540 rows
#   EZPW: 1540 rows
#   C: 5 rows
#   NVDA: 5 rows
#   MNST: 1540 rows
#   SCHH: 5 rows
#   CI: 1540 rows
#   MS: 5 rows
#   DAL: 1540 rows
#   BSX: 1540 rows
#   AIN: 1540 rows
#   ZBRA: 1540 rows
#   INCY: 1540 rows
#   IAC: 1540 rows
#   PECO: 1251 rows
#   TRIP: 1540 rows
#   HUBG: 1540 rows
#   JOE: 1540 rows
#   PRU: 5 rows
#   RDNT: 1540 rows
#   SBSI: 1540 rows
#   VIAV: 1540 rows
#   PBW: 5 rows
#   CRI: 1540 rows
#   DEI: 1540 rows
#   WSM: 1540 rows
#   DAN: 1540 rows
#   HST: 1540 rows
#   MCW: 1167 rows
#   CALX: 1540 rows
#   NPK: 1540 rows
#   HRL: 1540 rows
#   RES: 1540 rows
#   MWA: 1540 rows
#   LYB: 1540 rows
#   GDEN: 1540 rows
#   RCL: 5 rows
#   VCEL: 1540 rows
#   JBSS: 1540 rows
#   VTR: 1540 rows
#   NBTB: 1540 rows
#   ESI: 1540 rows
#   VXUS: 5 rows
#   NOW: 5 rows
#   KEYS: 1540 rows
#   SPY: 5 rows
#   PLD: 5 rows
#   SPXU: 5 rows
#   KRE: 5 rows
#   DORM: 1540 rows
#   BITQ: 5 rows
#   FELE: 1540 rows
#   CPT: 1540 rows
#   WSC: 1540 rows
#   SNOW: 5 rows
#   KFY: 1540 rows
#   LTC: 1540 rows
#   CPAY: 1540 rows
#   WST: 1540 rows
#   UNF: 1540 rows
#   BLFS: 1540 rows
#   DRH: 1540 rows
#   TKO: 1540 rows
#   EFX: 1540 rows
#   IYE: 5 rows
#   KMI: 5 rows
#   STEP: 1362 rows
#   AROC: 1540 rows
#   TRMK: 1540 rows
#   AGYS: 1540 rows
#   EWJ: 5 rows
#   VHT: 5 rows
#   ICHR: 1540 rows
#   VGT: 5 rows
#   SCL: 1540 rows
#   VGK: 5 rows
#   ADEA: 1540 rows
#   GEO: 1540 rows
#   ATEN: 1540 rows
#   LEG: 1540 rows
#   AVGO: 5 rows
#   AEP: 5 rows
#   FBRT: 1087 rows
#   APD: 5 rows
#   UNM: 5 rows
#   LII: 1540 rows
#   EWY: 5 rows
#   WINA: 1540 rows
#   PPL: 1540 rows
#   STRA: 1540 rows
#   STAA: 1540 rows
#   T: 5 rows
#   ENVA: 1540 rows
#   CAKE: 1540 rows
#   MHO: 1540 rows
#   EIG: 1540 rows
#   WY: 1540 rows
#   SKYY: 5 rows
#   USO: 5 rows
#   MLM: 1540 rows
#   APOG: 1540 rows
#   PEB: 1540 rows
#   HAFC: 1540 rows
#   KBWP: 5 rows
#   IAU: 5 rows
#   ADI: 1540 rows
#   PFBC: 1540 rows
#   CRSR: 1357 rows
#   CERT: 1301 rows
#   FOX: 1540 rows
#   UVXY: 5 rows
#   RVTY: 1540 rows
#   RNG: 1540 rows
#   QTWO: 1540 rows
#   TMDX: 1540 rows
#   IJH: 5 rows
#   AMZN: 5 rows
#   MAC: 1540 rows
#   RSP: 5 rows
#   CDNS: 1540 rows
#   BITI: 5 rows
#   HDV: 5 rows
#   INVX: 1540 rows
#   JBGS: 1540 rows
#   SDY: 5 rows
#   WAFD: 1540 rows
#   LIT: 5 rows
#   REGN: 1540 rows
#   LPG: 1540 rows
#   UAA: 1540 rows
#   MMSI: 1540 rows
#   PEG: 1540 rows
#   UA: 1540 rows
#   QLD: 5 rows
#   CBOE: 1540 rows
#   CARG: 1540 rows
#   SHW: 5 rows
#   KBE: 5 rows
#   ROP: 1540 rows
#   SCHW: 5 rows
#   MSI: 1540 rows
#   STE: 1540 rows
#   DE: 5 rows
#   YELP: 1540 rows
#   VTOL: 1540 rows
#   PARR: 1540 rows
#   CVI: 1540 rows
#   BALL: 1540 rows
#   SPSC: 1540 rows
#   LZ: 1164 rows
#   IDXX: 1540 rows
#   PGR: 5 rows
#   CNR: 1540 rows
#   REMX: 5 rows
#   DGRO: 5 rows
#   PRAA: 1540 rows
#   DBB: 5 rows
#   AES: 1540 rows
#   HP: 1540 rows
#   FCF: 1540 rows
#   PFS: 1540 rows
#   ETN: 5 rows
#   PSMT: 1540 rows
#   KRYS: 1540 rows
#   PTCT: 1540 rows
#   FMC: 1540 rows
#   LKQ: 1540 rows
#   CNC: 1540 rows
#   WDC: 1540 rows
#   FUN: 1540 rows
#   PENG: 1540 rows
#   TJX: 5 rows
#   IEF: 5 rows
#   RDN: 1540 rows
#   TTD: 1540 rows
#   MARA: 1540 rows
#   RAMP: 1540 rows
#   BNO: 5 rows
#   TPH: 1540 rows
#   LH: 1540 rows
#   HPQ: 1540 rows
#   ROK: 1540 rows
#   VTV: 5 rows
#   PGNY: 1540 rows
#   AX: 1540 rows
#   CENX: 1540 rows
#   ARE: 1540 rows
#   MBIN: 1540 rows
#   TT: 1540 rows
#   AKR: 1540 rows
#   PI: 1540 rows
#   ULTA: 1540 rows
#   SDGR: 1516 rows
#   SLB: 5 rows
#   OMC: 1540 rows
#   CORN: 5 rows
#   NEE: 5 rows
#   CPK: 1540 rows
#   EXR: 1540 rows
#   ROG: 1540 rows
#   EXPI: 1540 rows
#   GKOS: 1540 rows
#   CAG: 1540 rows
#   FIS: 1540 rows
#   MTH: 1540 rows
#   LNC: 5 rows
#   TRMB: 1540 rows
#   AMD: 5 rows
#   IOSP: 1540 rows
#   FICO: 1540 rows
#   LUV: 1540 rows
#   BATT: 5 rows
#   SPHD: 5 rows
#   THRM: 1540 rows
#   HSY: 5 rows
#   BKNG: 5 rows
#   OKE: 1540 rows
#   CVCO: 1540 rows
#   POWI: 1540 rows
#   EQR: 1540 rows
#   VTI: 5 rows
#   MPC: 5 rows
#   EPC: 1540 rows
#   ALG: 1540 rows
#   PLXS: 1540 rows
#   AVNS: 1540 rows
#   VDE: 5 rows
#   KHC: 1540 rows
#   POWL: 1540 rows
#   EOG: 5 rows
#   MOS: 1540 rows
#   FTRE: 670 rows
#   PDFS: 1540 rows
#   DECK: 1540 rows
#   FFIV: 1540 rows
#   WEN: 1540 rows
#   JNK: 5 rows
#   LRCX: 1540 rows
#   CSGS: 1540 rows
#   SHV: 5 rows
#   PATK: 1540 rows
#   DGX: 1540 rows
#   STZ: 1540 rows
#   PNW: 1540 rows
#   CAT: 5 rows
#   AAMI: 1540 rows
#   A: 1540 rows
#   ANIP: 1540 rows
#   DG: 1540 rows
#   GEV: 475 rows
#   XME: 5 rows
#   GWW: 1540 rows
#   SUPN: 1540 rows
#   KALU: 1540 rows
#   CRK: 1540 rows
#   DV: 1213 rows
#   EQIX: 5 rows
#   ITW: 1540 rows
#   RXO: 829 rows
#   AZZ: 1540 rows
#   CZR: 1540 rows
#   MRTN: 1540 rows
#   BXMT: 1540 rows
#   MBC: 799 rows
#   SNA: 1540 rows
#   GIII: 1540 rows
#   EXPE: 1540 rows
#   CPB: 1540 rows
#   XLF: 5 rows
#   EL: 1540 rows
#   STC: 1540 rows
#   DFH: 1275 rows
#   CATY: 1540 rows
#   MMI: 1540 rows
#
# Updated: 1260 | Up to date: 0 | No new data: 28
# WARNING: 28 tickers returned no data: ['OSW', 'IPG', 'NSP', 'OI', 'OFG', 'OGN', 'OXM', 'OSIS', 'NXRT', 'WBA', 'NWN', 'AAPL', 'IEU', 'NWL', 'CWEN.A', 'NWBI', 'NTCT', 'OUT', 'K', 'MOG.A', 'GOOGL', 'FI', 'NVRI', 'MSFT', 'BF.B', 'BRK.B', 'NX', 'OII']
# Done.

# %%
## Verification
from research.functions.load_data import load_prices

df = load_prices(tickers=TICKERS, start_date=START_DATE, end_date=end_date)
print(f"Total rows loaded: {len(df):,}")
print(f"Tickers with data: {df['ticker'].nunique()} / {len(TICKERS)}")
print(f"Date range: {df['date'].min()} → {df['date'].max()}")

counts = df.groupby("ticker").size()
median_rows = counts.median()
sparse = counts[counts < median_rows * 0.5]
if not sparse.empty:
    print(f"\nWARNING: {len(sparse)} tickers have < 50% of median row count:")
    print(sparse.to_string())
else:
    print("\nAll tickers have reasonable data coverage.")
# Out:
# Total rows loaded: 1,904,363
# Tickers with data: 1263 / 1288
# Date range: 2020-01-02 00:00:00 → 2026-02-18 00:00:00
#
# WARNING: 22 tickers have < 50% of median row count:
# ticker
# AESI    739
# AMTM    351
# BTSG    517
# CON     393
# CURB    349
# ECG     327
# FTRE    670
# GEV     475
# KGS     662
# KVUE    700
# MRP     260
# NATL    590
# PHIN    663
# RAL     164
# SEZL    610
# SOLS     83
# SOLV    476
# VLTO    595
# VSNT     44
# VSTS    600
# WAY     425
# WS      557
